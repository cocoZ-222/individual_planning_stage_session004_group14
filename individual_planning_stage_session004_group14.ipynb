# %%
library(tidyverse)
library(repr)
library(tidymodels)
options(repr.matrix.max.rows = 6)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# ── Attaching packages ────────────────────────────────────── tidymodels 1.1.1 ──
#
# ✔ broom        1.0.6     ✔ rsample      1.2.1
# ✔ dials        1.3.0     ✔ tune         1.1.2
# ✔ infer        1.0.7     ✔ workflows    1.1.4
# ✔ modeldata    1.4.0     ✔ workflowsets 1.0.1
# ✔ parsnip      1.2.1     ✔ yardstick    1.3.1
# ✔ recipes      1.1.0
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ...

# %%
players <- read_csv("players.csv")
players
sessions <- read_csv("sessions.csv")
sessions
# Out:
# Rows: 196 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, Age
# lgl (1): subscribe
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     experience subscribe
# 1   Pro         TRUE
# 2   Veteran     TRUE
# 3   Veteran    FALSE
# ⋮   ⋮          ⋮
# 194 Amateur    FALSE
# 195 Amateur    FALSE
# 196 Pro         TRUE
#     hashedEmail
# 1   f6daba428a5e19a3d47574858c13550499be23603422e6a0ee9728f8b53e192d
# 2   f3c813577c458ba0dfef80996f8f32c93b6e8af1fa939732842f2312358a88e9
# 3   b674dd7ee0d24096d1c019615ce4d12b20fcbff12d79d3c5a9d2118eb7ccbb28
# ⋮   ⋮
# 194 d572f391d452b76ea2d7e5e53a3d38bfd7499c7399db299bd4fedb06a46ad5bb
# 195 f19e136ddde68f365afc860c725ccff54307dedd13968e896a9f890c40aea436
# ...

# %%
players_use <- players|>
select(subscribe, played_hours, Age)|>
mutate(subscribe = as.integer(subscribe))
players_use
# Out:
#     subscribe played_hours Age
# 1   1         30.3          9
# 2   1          3.8         17
# 3   0          0.0         17
# ⋮   ⋮         ⋮            ⋮
# 194 0         0.0          57
# 195 0         2.3          17
# 196 1         0.2          NA

# %%
mean_table <- players |>
  summarize(
    mean_playing_hours = mean(played_hours, na.rm = TRUE),
    mean_players_age = mean(Age, na.rm = TRUE)
  )
mean_table

age_mean <- players |>
  group_by(Age)|>
  summarize(
    mean_playing_hours = mean(played_hours, na.rm = TRUE),
  )
age_mean

experience_mean <- players |>
  group_by(experience)|>
  summarize(
    mean_playing_hours = mean(played_hours, na.rm = TRUE),
  )
experience_mean

gender_mean <- players |>
  group_by(gender)|>
  summarize(
    mean_playing_hours = mean(played_hours, na.rm = TRUE),
  )
gender_mean
# Out:
#   mean_playing_hours mean_players_age
# 1 5.845918           21.13918
#    Age mean_playing_hours
# 1   9  30.3
# 2  10   3.6
# 3  11   2.9
# ⋮  ⋮   ⋮
# 31 57  0.00
# 32 58  0.30
# 33 NA  0.15
#   experience mean_playing_hours
# 1 Amateur     6.0174603
# 2 Beginner    1.2485714
# 3 Pro         2.6000000
# 4 Regular    18.2083333
# 5 Veteran     0.6479167
#   gender            mean_playing_hours
# 1 Agender            6.250000
# 2 Female            10.635135
# 3 Male               4.127419
# ⋮ ⋮                 ⋮
# 5 Other             0.20000000
# 6 Prefer not to say 0.37272727
# 7 Two-Spirited      0.08333333

# %%
age_plot <- players|>
ggplot(aes(x=Age, y=played_hours))+
geom_point()+
labs(x = "Ages", y = "Played Hours")+
ggtitle("Relationship between played hours and ages")
age_plot

age_mean_plot <- age_mean|>
ggplot(aes(x=Age, y=mean_playing_hours))+
geom_point()+
labs(x = "Ages", y = "Mean Played Hours")+
ggtitle("Relationship between mean played hours and ages")
age_mean_plot
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title
# plot without title

# %%
subscribe_plot <- ggplot(data = players, aes(x = factor(Age), fill = subscribe)) +
  geom_bar(position = "dodge") +
  labs(
    title = "Subscriber Count by Age",
    x = "Age",
    y = "Count",
    fill = "Subscription Status" 
  ) 
subscribe_plot
# Out:
# plot without title
